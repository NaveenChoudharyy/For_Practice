# %% [markdown]
# # Netflix Movies and TV Shows

# %% [markdown]
# #### About this Dataset:
# Netflix is one of the most popular media and video streaming platforms. They have over 8000 movies or tv shows available on their platform, as of mid-2021, they have over 200M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.
#
#
# #### Interesting Task Ideas
#
# 1. Understanding what content is available in different countries
# 2. Identifying similar content by matching text-based features
# 3. Network analysis of Actors / Directors and find interesting insights
# 4. Does Netflix has more focus on TV Shows than movies in recent years.
#
#
# #### Source of Dataset : https://www.kaggle.com/datasets/shivamb/netflix-shows

# %% [markdown]
# ######

# %%
# Importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing all worksheets

movies_shows = pd.read_excel("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/netflix_titles.xlsx", sheet_name='netflix_titles')
directors = pd.read_excel("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/netflix_titles.xlsx", sheet_name='netflix_titles_directors')
countries = pd.read_excel("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/netflix_titles.xlsx", sheet_name='netflix_titles_countries')
cast = pd.read_excel("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/netflix_titles.xlsx", sheet_name='netflix_titles_cast')
category = pd.read_excel("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/netflix_titles.xlsx", sheet_name='netflix_titles_category')

# %% [markdown]
# ##### Alalysis will be done show_id wise

# %% [markdown]
# ###### EDA on movies

# %%
movies_shows
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6231              NaN               13  TV Show
# 6232              NaN                4  TV Show
# 6233               60              NaN    Movie
# 6234              NaN                2  TV Show
# 6235              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# 4                                    #realityhigh  2017-09-08 00:00:00
# ...                                           ...                  ...
# 6231                                 Red vs. Blue                  NaN
# 6232                                        Maron                  NaN
# 6233       Little Baby Bum: Nursery Rhyme Friends                  NaN
# 6234  A Young Doctor's Notebook and Other Stories                  NaN
# 6235                                      Friends                  NaN
#
#       release_year    rating  \
# 0           2019.0     TV-PG
# 1           2016.0     TV-MA
# 2           2013.0  TV-Y7-FV
# 3           2016.0     TV-Y7
# 4           2017.0     TV-14
# ...            ...       ...
# 6231        2015.0        NR
# 6232        2016.0     TV-MA
# 6233        2016.0       NaN
# 6234        2013.0     TV-MA
# 6235        2003.0     TV-14
#
#                                             description     show_id
# 0     Before planning an awesome wedding for his gra...  81145628.0
# 1     Jandino Asporaat riffs on the challenges of ra...  80117401.0
# 2     With the help of three human allies, the Autob...  70234439.0
# 3     When a prison ship crash unleashes hundreds of...  80058654.0
# 4     When nerdy high schooler Dani finally attracts...  80125979.0
# ...                                                 ...         ...
# 6231  This parody of first-person shooter games, mil...  80000063.0
# 6232  Marc Maron stars as Marc Maron, who interviews...  70286564.0
# 6233  Nursery rhymes and original music for children...  80116008.0
# 6234  Set during the Russian Revolution, this comic ...  70281022.0
# 6235  This hit sitcom follows the merry misadventure...  70153404.0
#
# [6236 rows x 9 columns]

# %%
# Count of duplicate records

movies_shows.duplicated().sum()

# No duplicate records found
# Out:
# 0

# %%
# Info about the data

movies_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   duration_minutes  4267 non-null   object
#  1   duration_seasons  1971 non-null   object
#  2   type              6235 non-null   object
#  3   title             6235 non-null   object
#  4   date_added        6223 non-null   object
#  5   release_year      6234 non-null   float64
#  6   rating            6223 non-null   object
#  7   description       6233 non-null   object
#  8   show_id           6232 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 438.6+ KB

# %%
# From the above we can understand that if 
# It is a movie then "duration_minutes" will be mentioned and "duration_seasons" will be null.
# And if it is a show then "duration_minutes" will be null and "duration_seasons" will be mentioned.


# As per this logic sum of count of not nulls in "duration_minutes" and "duration_seasons" should be 6236 or less.

# %%
# logic 1

movies_shows[movies_shows.duration_minutes.notnull() & movies_shows.duration_seasons.notnull()]
# Out:
#           duration_minutes     duration_seasons  type  title  \
# 2018      Flying Fortress"  2017-03-31 00:00:00  1944  TV-PG
# 4525   and probably will."             80188902   NaN    NaN
#
#                                              date_added  release_year rating  \
# 2018  This documentary centers on the crew of the B-...    80119194.0    NaN
# 4525                                                NaN           NaN    NaN
#
#      description  show_id
# 2018         NaN      NaN
# 4525         NaN      NaN

# %%
# There are 2 records in which "duration_minutes" and "duration_seasons" contains not nulls.
# But these contains unrealted informations in some fileds so these should be deleted.


movies_shows = movies_shows.drop(index=[2018, 4525])

# %%
# logic 2

movies_shows[movies_shows.duration_minutes.isnull() & movies_shows.duration_seasons.isnull()]


# There is no record in which both "duration_minutes" and "duration_seasons" are null
# Out:
# Empty DataFrame
# Columns: [duration_minutes, duration_seasons, type, title, date_added, release_year, rating, description, show_id]
# Index: []

# %%
movies_shows['duration'] = np.where(movies_shows.duration_seasons.isna(), 
                                    movies_shows.duration_minutes, movies_shows.duration_seasons)

# %%
movies_shows = movies_shows.drop(columns=['duration_seasons', 'duration_minutes'])
movies_shows.head()
# Out:
#       type                                    title           date_added  \
# 0    Movie  Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1    Movie               Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2  TV Show                       Transformers Prime  2018-09-08 00:00:00
# 3  TV Show         Transformers: Robots in Disguise  2018-09-08 00:00:00
# 4    Movie                             #realityhigh  2017-09-08 00:00:00
#
#    release_year    rating                                        description  \
# 0        2019.0     TV-PG  Before planning an awesome wedding for his gra...
# 1        2016.0     TV-MA  Jandino Asporaat riffs on the challenges of ra...
# 2        2013.0  TV-Y7-FV  With the help of three human allies, the Autob...
# 3        2016.0     TV-Y7  When a prison ship crash unleashes hundreds of...
# 4        2017.0     TV-14  When nerdy high schooler Dani finally attracts...
#
#       show_id duration
# 0  81145628.0       90
# 1  80117401.0       94
# 2  70234439.0        1
# 3  80058654.0        1
# 4  80125979.0       99

# %%
# Getting null counts for movies_shows

movies_shows.isna().sum()
# Out:
# type             0
# title            0
# date_added      12
# release_year     1
# rating          11
# description      1
# show_id          2
# duration         0
# dtype: int64

# %%
# date_added, release_year, rating, description, show_id contains very lesser number of nulls
# Checking the records where these contains nulls 

rec_having_nulls = movies_shows[movies_shows.date_added.isna() | movies_shows.release_year.isna() 
                         | movies_shows.rating.isna() | movies_shows.description.isna() | movies_shows.show_id.isna()]


rec_having_nulls


# They are very lesser number of records so we can drop them for better analysis
# Out:
#          type                                              title  \
# 211     Movie                              Louis C.K.: Hilarious
# 2017    Movie                    The Memphis Belle: A Story of a
# 2412    Movie                               My Honor Was Loyalty
# 3289    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 4057  TV Show                                       Little Lunch
# 4403    Movie  Fireplace 4K: Classic Crackling Fireplace from...
# 4404    Movie  Fireplace 4K: Crackling Birchwood from Firepla...
# 4524    Movie                            The Bad Education Movie
# 4708  TV Show                  Gargantia on the Verdurous Planet
# 5017    Movie               Louis C.K.: Live at the Comedy Store
# 5236    Movie                                    Louis C.K. 2017
# 6225  TV Show                                    Gunslinger Girl
# 6226  TV Show                    Anthony Bourdain: Parts Unknown
# 6227  TV Show                                            Frasier
# 6228  TV Show                                La Familia P. Luche
# 6229  TV Show                       The Adventures of Figaro Pho
# 6230  TV Show                                           Kikoriki
# 6231  TV Show                                       Red vs. Blue
# 6232  TV Show                                              Maron
# 6233    Movie             Little Baby Bum: Nursery Rhyme Friends
# 6234  TV Show        A Young Doctor's Notebook and Other Stories
# 6235  TV Show                                            Friends
#
#                date_added  release_year rating  \
# 211   2016-09-16 00:00:00        2010.0    NaN
# 2017                  NaN           NaN    NaN
# 2412  2017-03-01 00:00:00        2015.0    NaN
# 3289  2017-01-26 00:00:00        2017.0    NaN
# 4057  2018-02-01 00:00:00        2015.0    NaN
# 4403  2015-12-21 00:00:00        2015.0    NaN
# 4404  2015-12-21 00:00:00        2015.0    NaN
# 4524  2018-12-15 00:00:00        2015.0  TV-MA
# 4708  2016-12-01 00:00:00        2013.0    NaN
# 5017  2016-08-15 00:00:00        2015.0    NaN
# 5236  2017-04-04 00:00:00        2017.0    NaN
# 6225                  NaN        2008.0  TV-14
# 6226                  NaN        2018.0  TV-PG
# 6227                  NaN        2003.0  TV-PG
# 6228                  NaN        2012.0  TV-14
# 6229                  NaN        2015.0  TV-Y7
# 6230                  NaN        2010.0   TV-Y
# 6231                  NaN        2015.0     NR
# 6232                  NaN        2016.0  TV-MA
# 6233                  NaN        2016.0    NaN
# 6234                  NaN        2013.0  TV-MA
# 6235                  NaN        2003.0  TV-14
#
#                                             description     show_id duration
# 211   Emmy-winning comedy writer Louis C.K. brings h...  70129452.0       84
# 2017                                                NaN         NaN       40
# 2412  Amid the chaos and horror of World War II, a c...  80144119.0      115
# 3289  Oprah Winfrey sits down with director Ava DuVe...  80169801.0       37
# 4057  Adopting a child's perspective, this show take...  80078037.0        1
# 4403  The first of its kind in UHD 4K, with the clea...  80092839.0       60
# 4404  For the first time in 4K Ultra-HD, everyone's ...  80092835.0       60
# 4524  Britain's most ineffective but caring teacher ...         NaN       87
# 4708  After falling through a wormhole, a space-dwel...  80039789.0        1
# 5017  The comic puts his trademark hilarious/thought...  80114111.0       66
# 5236  Louis C.K. muses on religion, eternal love, gi...  80161109.0       74
# 6225  On the surface, the Social Welfare Agency appe...  70204989.0        2
# 6226  This CNN original series has chef Anthony Bour...  70304979.0        5
# 6227  Frasier Crane is a snooty but lovable Seattle ...  70153412.0       11
# 6228  This irreverent sitcom featues Ludovico, Feder...  70243132.0        3
# 6229  Imagine your worst fears, then multiply them: ...  80005756.0        2
# 6230  A wacky rabbit and his gang of animal pals hav...  80159925.0        2
# 6231  This parody of first-person shooter games, mil...  80000063.0       13
# 6232  Marc Maron stars as Marc Maron, who interviews...  70286564.0        4
# 6233  Nursery rhymes and original music for children...  80116008.0       60
# 6234  Set during the Russian Revolution, this comic ...  70281022.0        2
# 6235  This hit sitcom follows the merry misadventure...  70153404.0       10

# %%
# Deleting records having nulls


movies_shows = movies_shows.drop(index=list(rec_having_nulls.index))

movies_shows
# Out:
#          type                                    title           date_added  \
# 0       Movie  Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1       Movie               Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2     TV Show                       Transformers Prime  2018-09-08 00:00:00
# 3     TV Show         Transformers: Robots in Disguise  2018-09-08 00:00:00
# 4       Movie                             #realityhigh  2017-09-08 00:00:00
# ...       ...                                      ...                  ...
# 6220  TV Show                  Talking Tom and Friends  2019-04-10 00:00:00
# 6221  TV Show                       Pokémon the Series  2019-04-01 00:00:00
# 6222  TV Show                              Justin Time  2016-04-01 00:00:00
# 6223  TV Show  Terrace House: Boys & Girls in the City  2016-04-01 00:00:00
# 6224  TV Show                                    Weeds  2014-04-01 00:00:00
#
#       release_year    rating  \
# 0           2019.0     TV-PG
# 1           2016.0     TV-MA
# 2           2013.0  TV-Y7-FV
# 3           2016.0     TV-Y7
# 4           2017.0     TV-14
# ...            ...       ...
# 6220        2017.0      TV-G
# 6221        2019.0  TV-Y7-FV
# 6222        2012.0      TV-Y
# 6223        2016.0     TV-14
# 6224        2012.0     TV-MA
#
#                                             description     show_id duration
# 0     Before planning an awesome wedding for his gra...  81145628.0       90
# 1     Jandino Asporaat riffs on the challenges of ra...  80117401.0       94
# 2     With the help of three human allies, the Autob...  70234439.0        1
# 3     When a prison ship crash unleashes hundreds of...  80058654.0        1
# 4     When nerdy high schooler Dani finally attracts...  80125979.0       99
# ...                                                 ...         ...      ...
# 6220  Full of funny one-liners and always ready for ...  80162994.0        2
# 6221  Ash and his Pikachu travel to the Alola region...  80186475.0        2
# 6222  In Justin's dreams, he and his imaginary frien...  70272742.0        2
# 6223  A new set of six men and women start their liv...  80067942.0        2
# 6224  A suburban mother starts selling marijuana to ...  70136122.0        8
#
# [6212 rows x 8 columns]

# %%
# Resetting the indexes

movies_shows = movies_shows.reset_index().drop(columns='index')
movies_shows.head()
# Out:
#       type                                    title           date_added  \
# 0    Movie  Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1    Movie               Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2  TV Show                       Transformers Prime  2018-09-08 00:00:00
# 3  TV Show         Transformers: Robots in Disguise  2018-09-08 00:00:00
# 4    Movie                             #realityhigh  2017-09-08 00:00:00
#
#    release_year    rating                                        description  \
# 0        2019.0     TV-PG  Before planning an awesome wedding for his gra...
# 1        2016.0     TV-MA  Jandino Asporaat riffs on the challenges of ra...
# 2        2013.0  TV-Y7-FV  With the help of three human allies, the Autob...
# 3        2016.0     TV-Y7  When a prison ship crash unleashes hundreds of...
# 4        2017.0     TV-14  When nerdy high schooler Dani finally attracts...
#
#       show_id duration
# 0  81145628.0       90
# 1  80117401.0       94
# 2  70234439.0        1
# 3  80058654.0        1
# 4  80125979.0       99

# %%
movies_shows.isna().sum()

# Now no nulls availables
# Out:
# type            0
# title           0
# date_added      0
# release_year    0
# rating          0
# description     0
# show_id         0
# duration        0
# dtype: int64

# %%
# EDA for column "type"

movies_shows.type.value_counts()

# Cardinality is only 2
# Out:
# type
# Movie      4255
# TV Show    1957
# Name: count, dtype: int64

# %%
# Correcting datatype of column "date_added"


movies_shows.date_added = pd.to_datetime(movies_shows.date_added, format= '%Y-%m-%d')

movies_shows.date_added
# Out:
# 0      2019-09-09
# 1      2016-09-09
# 2      2018-09-08
# 3      2018-09-08
# 4      2017-09-08
#           ...
# 6207   2019-04-10
# 6208   2019-04-01
# 6209   2016-04-01
# 6210   2016-04-01
# 6211   2014-04-01
# Name: date_added, Length: 6212, dtype: datetime64[ns]

# %%
# We can extract month, month_name and year from "date_added" column


movies_shows['added_year'] = movies_shows.date_added.dt.year
movies_shows['added_month'] = movies_shows.date_added.dt.month
movies_shows['added_month_name'] = movies_shows.date_added.dt.month_name()


movies_shows.head()
# Out:
#       type                                    title date_added  release_year  \
# 0    Movie  Norm of the North: King Sized Adventure 2019-09-09        2019.0
# 1    Movie               Jandino: Whatever it Takes 2016-09-09        2016.0
# 2  TV Show                       Transformers Prime 2018-09-08        2013.0
# 3  TV Show         Transformers: Robots in Disguise 2018-09-08        2016.0
# 4    Movie                             #realityhigh 2017-09-08        2017.0
#
#      rating                                        description     show_id  \
# 0     TV-PG  Before planning an awesome wedding for his gra...  81145628.0
# 1     TV-MA  Jandino Asporaat riffs on the challenges of ra...  80117401.0
# 2  TV-Y7-FV  With the help of three human allies, the Autob...  70234439.0
# 3     TV-Y7  When a prison ship crash unleashes hundreds of...  80058654.0
# 4     TV-14  When nerdy high schooler Dani finally attracts...  80125979.0
#
#   duration  added_year  added_month added_month_name
# 0       90        2019            9        September
# 1       94        2016            9        September
# 2        1        2018            9        September
# 3        1        2018            9        September
# 4       99        2017            9        September

# %%
# EDA for column "rating"


movies_shows.rating.value_counts()
# Out:
# rating
# TV-MA       2024
# TV-14       1695
# TV-PG        698
# R            508
# PG-13        286
# NR           217
# PG           184
# TV-Y7        168
# TV-G         149
# TV-Y         142
# TV-Y7-FV      95
# G             37
# UR             7
# NC-17          2
# Name: count, dtype: int64

# %%
# Correction of datatype in column "release_year"

movies_shows.release_year = movies_shows.release_year.astype(int)

movies_shows.release_year.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6212 entries, 0 to 6211
# Series name: release_year
# Non-Null Count  Dtype
# --------------  -----
# 6212 non-null   int32
# dtypes: int32(1)
# memory usage: 24.4 KB

# %%
# Correction of datatype of column "show_id"

movies_shows.show_id = movies_shows.show_id.astype(int)

# %%
# Checking if duplicates available in column "show_id"

movies_shows.show_id.duplicated().sum()

# No duplicates available.
# Out:
# 0

# %%
# EDA for "title" and "description"


movies_shows[['title', 'description']].duplicated().sum()
# Out:
# 1

# %%
# There is one movie having same name and same desciption
# As "show_id" contains only unique so why this contains duplicate, lets check


movies_shows[movies_shows[['title', 'description']].duplicated()]
# Out:
#        type   title date_added  release_year rating  \
# 2122  Movie  Sarkar 2019-03-02          2018  TV-MA
#
#                                             description   show_id duration  \
# 2122  A ruthless businessman’s mission to expose ele...  81072516      162
#
#       added_year  added_month added_month_name
# 2122        2019            3            March

# %%
movies_shows[movies_shows.title == 'Sarkar']
# Out:
#        type   title date_added  release_year rating  \
# 2121  Movie  Sarkar 2019-03-02          2018  TV-MA
# 2122  Movie  Sarkar 2019-03-02          2018  TV-MA
#
#                                             description   show_id duration  \
# 2121  A ruthless businessman’s mission to expose ele...  81075235      162
# 2122  A ruthless businessman’s mission to expose ele...  81072516      162
#
#       added_year  added_month added_month_name
# 2121        2019            3            March
# 2122        2019            3            March

# %%
# So above movies are same and having same  charaterstics but having different "show_id".
# This doesn't makes sense, so we can drop one on these record
# Dropping record having index as 2122

movies_shows = movies_shows.drop(index=2122)


# Resetting the indexes

movies_shows = movies_shows.reset_index().drop(columns='index')


movies_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6211 entries, 0 to 6210
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              6211 non-null   object
#  1   title             6211 non-null   object
#  2   date_added        6211 non-null   datetime64[ns]
#  3   release_year      6211 non-null   int32
#  4   rating            6211 non-null   object
#  5   description       6211 non-null   object
#  6   show_id           6211 non-null   int32
#  7   duration          6211 non-null   object
#  8   added_year        6211 non-null   int32
#  9   added_month       6211 non-null   int32
#  10  added_month_name  6211 non-null   object
# dtypes: datetime64[ns](1), int32(4), object(6)
# memory usage: 436.8+ KB

# %%
# EDA on column "title"

movies_shows.title.duplicated().sum()
# Out:
# 60

# %%
# There are 60 duplicate movie or show names, lets wheck whuch are they


movies_shows[movies_shows.title.isin(list(movies_shows.loc[movies_shows.title.duplicated(), 
                                                           'title']))].sort_values(by='title')


# There are some movies and tv shows having same names.

# there are some movies and tv shows which are having remake 
# as those have same names but different description and other charterstics
# Out:
#          type                    title date_added  release_year rating  \
# 5893  TV Show                 Aquarius 2017-06-16          2016  TV-MA
# 3436    Movie                 Aquarius 2017-01-13          2016     UR
# 1968    Movie                    Benji 2018-03-06          1974      G
# 2156    Movie                    Benji 2018-03-16          2018  TV-PG
# 5712  TV Show                   Bleach 2018-11-03          2006  TV-14
# ...       ...                      ...        ...           ...    ...
# 2317    Movie  Wet Hot American Summer 2019-03-01          2001      R
# 3127    Movie                      Zoo 2018-07-01          2018  TV-MA
# 5644  TV Show                      Zoo 2017-10-03          2017  TV-14
# 3451    Movie                     Zoom 2020-01-11          2006     PG
# 4558    Movie                     Zoom 2016-12-15          2015     NR
#
#                                             description   show_id duration  \
# 5893  Amid the turmoil of 1960s LA, two cops and a p...  80026224        2
# 3436  The final holdout in her historic beachside bu...  80113667      146
# 1968  After lovable abandoned mutt Benji is adopted ...    296682       86
# 2156  A determined dog comes to the rescue and helps...  80204923       87
# 5712  After teenager Ichigo Kurosaki acquires superp...  70204957        3
# ...                                                 ...       ...      ...
# 2317  Everyone wants a final shot at action on the l...  60021299       98
# 3127  A drug dealer starts having doubts about his t...  80993648       94
# 5644  When animal species all over the world begin a...  80011206        3
# 3451  Dragged from civilian life, a former superhero...  81221873       88
# 4558  Comic book artist Emma draws her ideal man: Ed...  80093812       93
#
#       added_year  added_month added_month_name
# 5893        2017            6             June
# 3436        2017            1          January
# 1968        2018            3            March
# 2156        2018            3            March
# 5712        2018           11         November
# ...          ...          ...              ...
# 2317        2019            3            March
# 3127        2018            7             July
# 5644        2017           10          October
# 3451        2020            1          January
# 4558        2016           12         December
#
# [115 rows x 11 columns]

# %%
# EDA on column "description"

movies_shows.description.duplicated().sum()
# Out:
# 7

# %%
# There are 60 duplicate movie or show descriptions, lets wheck whuch are they


movies_shows[movies_shows.description.isin(list(movies_shows.loc[movies_shows.description.duplicated(), 
                                                           'description']))].sort_values(by='description')


# There are some movies shows having same description.

# This is because they might got released in different laguage or might got added in different years on Netflix.
# As the number of duplicate descripion is very low, so it will not add any value to the data,
# we can drop duplicates as apart from "date_added" and "title" all the charatersitcs are same.
# Out:
#        type                                      title date_added  \
# 119   Movie                       Oh! Baby (Malayalam) 2019-09-25
# 120   Movie                           Oh! Baby (Tamil) 2019-09-25
# 251   Movie                                   Oh! Baby 2019-09-14
# 3180  Movie                    Solo: A Star Wars Story 2019-01-09
# 3181  Movie  Solo: A Star Wars Story (Spanish Version) 2019-01-09
# 5177  Movie                     Petta (Telugu Version) 2019-04-07
# 5201  Movie                                      Petta 2019-04-05
# 2309  Movie        Sarvam Thaala Mayam (Tamil Version) 2019-03-01
# 5171  Movie       Sarvam Thaala Mayam (Telugu Version) 2019-04-08
# 4869  Movie                  Game Over (Hindi Version) 2019-08-21
# 4870  Movie                  Game Over (Tamil Version) 2019-08-21
# 3238  Movie                          The Incredibles 2 2019-01-30
# 3747  Movie            Incredibles 2 (Spanish Version) 2019-02-08
#
#       release_year rating                                        description  \
# 119           2019  TV-14  A surly septuagenarian gets another chance at ...
# 120           2019  TV-14  A surly septuagenarian gets another chance at ...
# 251           2019  TV-14  A surly septuagenarian gets another chance at ...
# 3180          2018  PG-13  A young Han Solo tries to settle an old score ...
# 3181          2018  PG-13  A young Han Solo tries to settle an old score ...
# 5177          2019  TV-14  An affable, newly appointed college warden pro...
# 5201          2019  TV-14  An affable, newly appointed college warden pro...
# 2309          2018  TV-14  An aspiring musician battles age-old caste div...
# 5171          2018  TV-14  An aspiring musician battles age-old caste div...
# 4869          2019  TV-MA  As a series of murders hit close to home, a vi...
# 4870          2019  TV-MA  As a series of murders hit close to home, a vi...
# 3238          2018     PG  When Elastigirl gets recruited for a high-prof...
# 3747          2018     PG  When Elastigirl gets recruited for a high-prof...
#
#        show_id duration  added_year  added_month added_month_name
# 119   81186758      146        2019            9        September
# 120   81186757      146        2019            9        September
# 251   81093951      157        2019            9        September
# 3180  80220814      135        2019            1          January
# 3181  81046962      135        2019            1          January
# 5177  81091424      170        2019            4            April
# 5201  81091423      170        2019            4            April
# 2309  81083971      131        2019            3            March
# 5171  81074135      131        2019            4            April
# 4869  81151880       98        2019            8           August
# 4870  81151877       98        2019            8           August
# 3238  80221639      118        2019            1          January
# 3747  81059388      118        2019            2         February

# %%
# Deleting records having duplicate "description", "type", "release_year" and "duration"

movies_shows = movies_shows.drop_duplicates(subset=['description', 'type', 'release_year', 'duration'], keep='first')


# Resetting the indexes

movies_shows = movies_shows.reset_index().drop(columns='index')

# %%
movies_shows
# Out:
#          type                                    title date_added  \
# 0       Movie  Norm of the North: King Sized Adventure 2019-09-09
# 1       Movie               Jandino: Whatever it Takes 2016-09-09
# 2     TV Show                       Transformers Prime 2018-09-08
# 3     TV Show         Transformers: Robots in Disguise 2018-09-08
# 4       Movie                             #realityhigh 2017-09-08
# ...       ...                                      ...        ...
# 6200  TV Show                  Talking Tom and Friends 2019-04-10
# 6201  TV Show                       Pokémon the Series 2019-04-01
# 6202  TV Show                              Justin Time 2016-04-01
# 6203  TV Show  Terrace House: Boys & Girls in the City 2016-04-01
# 6204  TV Show                                    Weeds 2014-04-01
#
#       release_year    rating  \
# 0             2019     TV-PG
# 1             2016     TV-MA
# 2             2013  TV-Y7-FV
# 3             2016     TV-Y7
# 4             2017     TV-14
# ...            ...       ...
# 6200          2017      TV-G
# 6201          2019  TV-Y7-FV
# 6202          2012      TV-Y
# 6203          2016     TV-14
# 6204          2012     TV-MA
#
#                                             description   show_id duration  \
# 0     Before planning an awesome wedding for his gra...  81145628       90
# 1     Jandino Asporaat riffs on the challenges of ra...  80117401       94
# 2     With the help of three human allies, the Autob...  70234439        1
# 3     When a prison ship crash unleashes hundreds of...  80058654        1
# 4     When nerdy high schooler Dani finally attracts...  80125979       99
# ...                                                 ...       ...      ...
# 6200  Full of funny one-liners and always ready for ...  80162994        2
# 6201  Ash and his Pikachu travel to the Alola region...  80186475        2
# 6202  In Justin's dreams, he and his imaginary frien...  70272742        2
# 6203  A new set of six men and women start their liv...  80067942        2
# 6204  A suburban mother starts selling marijuana to ...  70136122        8
#
#       added_year  added_month added_month_name
# 0           2019            9        September
# 1           2016            9        September
# 2           2018            9        September
# 3           2018            9        September
# 4           2017            9        September
# ...          ...          ...              ...
# 6200        2019            4            April
# 6201        2019            4            April
# 6202        2016            4            April
# 6203        2016            4            April
# 6204        2014            4            April
#
# [6205 rows x 11 columns]

# %% [markdown]
# ###### EDA on directors

# %%
directors.head()
# Out:
#             director   show_id
# 0       Richard Finn  81145628
# 1   Fernando Lebrija  80125979
# 2        Gabe Ibáñez  70304989
# 3       Rodrigo Toro  80164077
# 4  Henrik Ruben Genz  70304990

# %%
directors.info()

# No nulls availabe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852 entries, 0 to 4851
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   director  4852 non-null   object
#  1   show_id   4852 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 75.9+ KB

# %%
# Checking for duplicates

directors.duplicated().sum()

# Dropping duplicates

directors = directors.drop_duplicates()

# %%
# Checking how many uniue values availabe

directors.nunique()
# Out:
# director    3655
# show_id     4265
# dtype: int64

# %%
# Checking how many movies directed by each director


cnt_of_movies_per_director = pd.DataFrame(directors.director.value_counts()).reset_index()
cnt_of_movies_per_director.columns = ['director', 'cnt_of_movies']

cnt_of_movies_per_director
# Out:
#              director  cnt_of_movies
# 0           Jan Suter             21
# 1         Raúl Campos             19
# 2        Marcus Raboy             14
# 3           Jay Karas             14
# 4         Jay Chapman             12
# ...               ...            ...
# 3650  Haissam Hussain              1
# 3651      Mitch Gould              1
# 3652    Kaizad Gustad              1
# 3653      Clay Porter              1
# 3654  Patrik Forsberg              1
#
# [3655 rows x 2 columns]

# %% [markdown]
# ###### EDA on Cast

# %%
cast.head()
# Out:
#                cast   show_id
# 0     Alan Marriott  81145628
# 1  Jandino Asporaat  80117401
# 2      Peter Cullen  70234439
# 3      Will Friedle  80058654
# 4      Nesta Cooper  80125979

# %%
cast.info()

# No nulls availabe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44311 entries, 0 to 44310
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cast     44311 non-null  object
#  1   show_id  44311 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 692.5+ KB

# %%
# Checking for duplicate records

print("Count of duplicate records : ", cast.duplicated().sum())

# Dropping this duplicate record

cast = cast.drop(index=list(cast[cast.duplicated()].index))


# Resetting the indexes

cast = cast.reset_index().drop(columns='index')


cast
# Out:
# Count of duplicate records :  1
#                    cast   show_id
# 0         Alan Marriott  81145628
# 1      Jandino Asporaat  80117401
# 2          Peter Cullen  70234439
# 3          Will Friedle  80058654
# 4          Nesta Cooper  80125979
# ...                 ...       ...
# 44305     Kaden Stephen  80108373
# 44306      Tonye Patano  70136122
# 44307      Rie Nakagawa  70204989
# 44308       Yomary Cruz  80000063
# 44309         Shaun Pye  70281022
#
# [44310 rows x 2 columns]

# %%
# Extracting the uniques value count from cast

cast.nunique()
# Out:
# cast       27405
# show_id     5664
# dtype: int64

# %% [markdown]
# ###### EDA on Countries

# %%
countries.head()
# Out:
#           country   show_id
# 0         Germany  80016401
# 1    South Africa  80182274
# 2   United States  80182274
# 3   United States  81145628
# 4  United Kingdom  80117401

# %%
countries.info()

# No duplicates available
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7179 entries, 0 to 7178
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  7179 non-null   object
#  1   show_id  7179 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 112.3+ KB

# %%
# Checking for duplicate records

print("Count of duplicate records : ", countries.duplicated().sum())


# No duplicate records found
# Out:
# Count of duplicate records :  0

# %%
# unique value count of countries

countries.nunique()
# Out:
# country     113
# show_id    5758
# dtype: int64

# %% [markdown]
# ###### EDA on category

# %%
category.head()
# Out:
#                   listed_in   show_id
# 0  Children & Family Movies  81145628
# 1           Stand-Up Comedy  80117401
# 2                  Kids' TV  70234439
# 3                  Kids' TV  80058654
# 4                  Comedies  80125979

# %%
category.info()

# No nulls available
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13670 entries, 0 to 13669
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   listed_in  13670 non-null  object
#  1   show_id    13670 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 213.7+ KB

# %%
# Checking for duplicate records

print("Count of duplicate records : ", category.duplicated().sum())
# Out:
# Count of duplicate records :  0

# %%
# Unique value counts

category.nunique()
# Out:
# listed_in      42
# show_id      6234
# dtype: int64

# %%
# Exporting the cleaned data into csv files for further analysis

movies_shows.to_csv("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/Cleaned_data/movies_shows.csv", index=False)
directors.to_csv("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/Cleaned_data/directors.csv", index=False)
cast.to_csv("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/Cleaned_data/cast.csv", index=False)
countries.to_csv("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/Cleaned_data/countries.csv", index=False)
category.to_csv("C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Data/Cleaned_data/category.csv", index=False)

# %% [markdown]
# # Extracting data for data analysis on excel

# %%
movies_shows_execl = movies_shows.drop(columns=['added_year','added_month', 'added_month_name'])

# %%
# Exporting the cleaned data into single excel file in different worksheets for further analysis on excel

writer = pd.ExcelWriter(path="C:/Users/navee/OneDrive/Desktop/GitHub/End_to_end_case_studies/Netflix/Excel/Netflix_data_analysis.xlsx", 
                        engine='xlsxwriter')

movies_shows_execl.to_excel(writer, sheet_name='movies_shows', index=False)
directors.to_excel(writer, sheet_name='directors', index=False)
cast.to_excel(writer, sheet_name='cast', index=False)
countries.to_excel(writer, sheet_name='countries', index=False)
category.to_excel(writer, sheet_name='category', index=False)

writer.close()

# %% [markdown]
# # ---------------------------------------------------END---------------------------------------------------
